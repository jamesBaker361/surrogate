# %%
import matplotlib.pyplot as plt
from random_edges_od import *

# %%
g=make_random_graph(n=20,f=.5,limit=10000)
nx.draw(g)
plt.show()

# %%
for e in g.edges():
    print(*e)
# Out:
# 0 17
# 0 16
# 1 7
# 2 3
# 3 17
# 3 18
# 4 6
# 4 14
# 5 10
# 5 8
# 5 7
# 6 11
# 7 9
# 9 11
# 10 12
# 13 17
# 14 16
# 14 19
# 15 16
